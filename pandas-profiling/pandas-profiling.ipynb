# %%
#import nessecerry libraries

import pandas as pd

# %%
df = pd.read_csv('mount_everest_deaths.csv')

# %%
df.head(10)
# Out:
#    No.                    Name          Date   Age  \
# 0    1                   Dorje  June 7, 1922   NaN
# 1    2                  Lhakpa  June 7, 1922   NaN
# 2    3                   Norbu  June 7, 1922   NaN
# 3    4                  Pasang  June 7, 1922   NaN
# 4    5                    Pema  June 7, 1922   NaN
# 5    6                   Sange  June 7, 1922   NaN
# 6    7                   Temba  June 7, 1922   NaN
# 7    8             Man Bahadur  May 13, 1924   NaN
# 8    9  Lance-Naik Shamsherpun  May 17, 1924   NaN
# 9   10           Andrew Irvine  June 9, 1924  22.0
#
#                               Expedition     Nationality  \
# 0  1922 British Mount Everest Expedition           Nepal
# 1  1922 British Mount Everest Expedition           Nepal
# 2  1922 British Mount Everest Expedition           Nepal
# 3  1922 British Mount Everest Expedition           Nepal
# 4  1922 British Mount Everest Expedition           Nepal
# ...

# %%
from pandas_profiling import ProfileReport
proof = ProfileReport(df)
proof.to_file(output_file='mount_everest_deaths.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13344/2501657250.py in <module>
# ----> 1 from pandas_profiling import ProfileReport
#       2 prof = ProfileReport(df)
#       3 prof.to_file(output_file='mount_everest_deaths.csv')
#
# ModuleNotFoundError: No module named 'pandas_profiling'
